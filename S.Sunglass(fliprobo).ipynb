# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
import pandas as pd
import numpy as np
import time

# %%
driver = webdriver.Chrome(r'chromedriver.exe')
driver.get('https://www.flipkart.com/')
sunglasses = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
sunglasses.send_keys('Sunglass')
enter = driver.find_element(By.CLASS_NAME, 'L0Z3Pu')
enter.click()

# %%
element_list = []
  
for page in range(1, 4):
    brand_name = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    product = driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
    glass_name = driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]' )
    
    
    for i in range(len(brand_name)):
         element_list.append([brand_name[i].text, product[i].text, glass_name[i].text])
            
#print(element_list)

driver.close()

# %%
pd.DataFrame(element_list, columns = ['Sunglass_brand', 'Description', 'Price'])[:100]
# Out:
#    Sunglass_brand                                        Description Price
# 0   VINCENT CHASE  by Lenskart Polarized, UV Protection Rectangul...  ₹849
# 1   VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...  ₹806
# 2      LIZA ANGEL  Riding Glasses, Night Vision Spectacle Sunglas...  ₹129
# 3       Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...  ₹149
# 4       Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...  ₹129
# ..            ...                                                ...   ...
# 95      New Specs   UV Protection Rectangular Sunglasses (Free Size)  ₹259
# 96  VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...  ₹949
# 97       PROVOGUE  Polarized, UV Protection Rectangular Sunglasse...  ₹664
# 98     LIZA ANGEL  UV Protection, Polarized Rectangular Sunglasse...  ₹129
# 99           SRPM  Night Vision, UV Protection Round Sunglasses (54)  ₹179
#
# [100 rows x 3 columns]
