# %%
import pandas as pd
import numpy as np
import selenium
from selenium import webdriver
import warnings 
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r'chromedriver.exe')
driver.get('https://www.naukri.com/')
designation = driver.find_element(By.CLASS_NAME, 'suggestor-input')
designation.send_keys('Data Analyst')
location = driver.find_element(By.XPATH, '/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys('Bangalore')

button = driver.find_element(By.CLASS_NAME, 'qsbSubmit')
button.click()

# %% [markdown]
# ### scrape the job-title, job-location, company_name, experience_required.

# %%
job = []
location = []
company = []
experience = []

job_title = driver.find_elements(By.XPATH, '//a[@class="title fw500 ellipsis"]')
for i in job_title[:10]:
    job_title = i.text
    job.append(job_title)

job_location = driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft fs12 lh16 locWdth"]')
for i in job_location[:10]:
    job_location = i.text
    location.append(job_location)
    
        

company_name =  driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in company_name[:10]:
    company_name = i.text
    company.append(company_name)  
    
experience_required = driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft fs12 lh16 expwdth"]')
for i in experience_required[:10]:
    experience_required = i.text
    experience.append(experience_required)

# %%
data = pd.DataFrame({'Job_Title':job, 'Job_Location':location, 'Company_Name':company, 'Experience_Required':experience})

# %%
data
# Out:
#                                            Job_Title  \
# 0                             Senior Data Analyst II
# 1                               Project Data Analyst
# 2                     Data Analyst, Business Analyst
# 3                                       Data Analyst
# 4                           Executive - Data Analyst
# 5  Data Analyst / Product Analyst / Business Analyst
# 6        Senior Data Analyst - Data Modeling/Quality
# 7                                Senior Data Analyst
# 8                                  Sr . Data Analyst
# 9                                       Data Analyst
#
#                                         Job_Location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2                 Bangalore/Bengaluru(HSR Layout +1)
# 3                    Temp. WFH - Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                   Bangalore/Bengaluru, Delhi / NCR
# ...

# %%
driver = webdriver.Chrome(r'chromedriver.exe')
driver.get('https://www.naukri.com/')
designation = driver.find_element(By.CLASS_NAME, 'suggestor-input')
designation.send_keys('Data Scientist')
location = driver.find_element(By.XPATH, '/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys('Bangalore')

button = driver.find_element(By.CLASS_NAME, 'qsbSubmit')
button.click()

# %%
job = []
location = []
company = []
experience = []

job_title = driver.find_elements(By.XPATH, '//a[@class="title fw500 ellipsis"]')
for i in job_title[:10]:
    job_title = i.text
    job.append(job_title)

job_location = driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft fs12 lh16 locWdth"]')
for i in job_location[:10]:
    job_location = i.text
    location.append(job_location)
    
        

company_name =  driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in company_name[:10]:
    company_name = i.text
    company.append(company_name)  
    
experience_required = driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft fs12 lh16 expwdth"]')
for i in experience_required[:10]:
    experience_required = i.text
    experience.append(experience_required)

# %%
data_scientist = pd.DataFrame({'Job_Title':job, 'Job_Location':location, 'Company_Name':company, 'Experience_Required':experience})
data_scientist
# Out:
#                                            Job_Title  \
# 0                   Analystics & Modeling Specialist
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                Data Scientist - II
# 5  Python Programming Language Data Science Pract...
# 6  ACN - Applied Intelligence - C4DI - Sustainabi...
# 7                                Lead Data Scientist
# 8                                Lead Data Scientist
# 9                 Data Science - Engineering Manager
#
#                                         Job_Location      Company_Name  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...         Accenture
# 1  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...       Tata Nexarc
# 2                  Bangalore/Bengaluru, Nagpur, Pune     Tech Mahindra
# 3  Hybrid - Bangalore/Bengaluru, Noida, Kolkata, ...  Mindtree Limited
# ...

# %% [markdown]
# ### The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

# %%
driver = webdriver.Chrome(r'chromedriver.exe')
driver.get('https://www.naukri.com/')
designation = driver.find_element(By.CLASS_NAME, 'suggestor-input')
designation.send_keys('Data Scientist')
#location = driver.find_element(By.XPATH, '/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
#location.send_keys('Bangalore')

button = driver.find_element(By.CLASS_NAME, 'qsbSubmit')
button.click()
time.sleep(10)
salary_button = driver.find_element(By.XPATH, "/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/i")
salary_button.click()
#location_button = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/i')
#location_button.click()
time.sleep(10)
loc_btn = driver.find_element(By.XPATH, "/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[4]/label/i")
loc_btn.click()

# %%
lists = []

for i in range(1,2):
    name = driver.find_elements(By.XPATH, '//a[@class="title fw500 ellipsis"]')
    loc = driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft fs12 lh16 locWdth"]')
    com = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
    ex = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 expwdth"]')

# %%
   for i in range(len(name)):
        lists.append([name[i].text, loc[i].text, com[i].text, ex[i].text])
#print(lists)

# %%
data = pd.DataFrame(lists, columns = ['Job_Title', 'Job_Location', 'Company_Name', 'Experience_Required'])[:10]

# %%
data
# Out:
#                                            Job_Title  \
# 0  Artificial Intelligence/Computer Vision Engine...
# 1          Data Activation Specialist - Adobe Target
# 2                  Data Scientist - Engine Algorithm
# 3  Opening For Jr. Data Scientist with Tatras Dat...
# 4                              SE/SSE-Data Scientist
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7  URGENT: Data Scientist | Gurugram | 5 Days Wor...
# 8                                     Data Scientist
# 9                                 Jr. Data Scientist
#
#                                         Job_Location  \
# 0  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 1  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 2  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 3                                        Delhi / NCR
# 4                                        Delhi / NCR
# 5  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...
# ...
