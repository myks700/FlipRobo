# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ###
# Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name ,Description and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to click on the List option from Dropdown menu on left side.
# 3. Then click on 50 most expensive cars in the world..
# 4. Then scrap the mentioned data and make the

# %%
driver = webdriver.Chrome(r'chromedriver.exe')
driver.get('https://www.motor1.com/')

click = driver.find_element(By.CLASS_NAME, "m1-hamburger-button")
click.click()

#dropdown = driver.find_element(By.XPATH, '//button[@class="dropdown-toggle"]')
#dropdown.click()
time.sleep(5)
features = driver.find_element(By.XPATH, '/html/body/div[4]/div[1]/div[3]/ul/li[5]')
features.click()

time.sleep(5)

most_exp = driver.find_element(By.XPATH, '/html/body/div[3]/div[8]/div/div[1]/div[1]/div[2]/a/picture/img')
most_exp.click()


#lists = driver.find_element(By.XPATH, '/html/body/div[3]/div[9]/div[1]/div[1]/div/div/div[2]/div/div[1]/h3/a')
#lists.click()

# %%
lists = []

for i in range(1,2):
    name = driver.find_elements(By.XPATH, '//h3[@class="subheader"]')
    #price = driver.find_elements(By.XPATH, '')

# %%
price = driver.find_elements(By.XPATH,'/html/body/div[3]/div[7]/div[2]/div[1]/div[2]/div[1]/p[4]/strong')

# %%
[i.text for i in price]
# Out:
# []

# %%
pd.DataFrame([i.text for i in name])
# Out:
#                                    0
# 0                          Drako GTE
# 1                      De Tomaso P72
# 2                  Ferrari LaFerrari
# 3                      Pagani Huayra
# 4                       McLaren Elva
# 5                        Czinger 21C
# 6                      Ferrari Monza
# 7                 Gordon Murray T.33
# 8                  Koenigsegg Gemera
# 9                        Zenvo TSR-S
# 10                Hennessey Venom F5
# 11                   Bentley Bacalar
# 12     Hispano Suiza Carmen Boulogne
# 13            Bentley Mulliner Batur
# 14                      Deus Vayanne
# 15                       SSC Tuatara
# 16                       Lotus Evija
# 17               Aston Martin Vulcan
# 18                        Delage D12
# 19                 McLaren Speedtail
# 20                      Rimac Nevera
# 21                     Pagani Utopia
# 22              Pininfarina Battista
# 23                 Ferrari FXX K Evo
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'lxml')
title = soup.find_all('p')
data = pd.DataFrame(title, columns = ['Description'])[4:50]

# %%
data
# Out:
#                                           Description
# 4                             [[Price: $1.2 Million]]
# 5   [The Drako GTE is a super sedan in every sense...
# 6                             [[Price: $1.3 Million]]
# 7   [The , [De Tomaso P72],  is basically the defi...
# 8                             [[Price: $1.4 Million]]
# 9   [At $1.4 million new, the Ferrari LaFerrari is...
# 10                            [[Price: $1.4 Million]]
# 11  [Inarguably one of the prettiest cars on this ...
# 12                            [[Price: $1.7 Million]]
# 13  [The , [McLaren Elva],  is one of the latest a...
# 14                            [[Price: $1.7 Million]]
# 15  [You might not know the name Czinger yet, but ...
# 16                            [[Price: $1.7 Million]]
# 17  [Much like the roof-less McLaren Elva, the , [...
# 18                            [[Price: $1.7 Million]]
# 19  [The second and slightly more affordable super...
# ...
